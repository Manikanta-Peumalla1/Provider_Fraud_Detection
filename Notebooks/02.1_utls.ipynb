# %%
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation and dataframes
from sklearn.model_selection import train_test_split  # For splitting data into train and test sets
from sklearn.ensemble import IsolationForest  # For anomaly detection
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load Model Input Data

# %%
# Read the processed model input data from CSV file
df=pd.read_csv("../Data/Processed/Model_Input_Data.csv")
# Print the dimensions of the dataset (rows, columns)
print(df.shape)
# Display the first 5 rows of the dataset
df.head()
# Out:
# (5410, 36)
#    Provider  PotentialFraud  IP_Claim_Count  IP_Benf_Count  \
# 0  PRV51001               0               5              5
# 1  PRV51003               1              62             53
# 2  PRV51004               0               0              0
# 3  PRV51005               1               0              0
# 4  PRV51007               0               3              3
#
#    Avg_IP_InscClaimAmtReimbursed  Avg_IP_DeductibleAmtPaid  \
# 0                   19400.000000                    1068.0
# 1                    9241.935484                    1068.0
# 2                       0.000000                       0.0
# 3                       0.000000                       0.0
# 4                    6333.333333                    1068.0
#
#    Avg_IP_Number_of_Days_in_Hospital  Avg_IP_Claim_Days  \
# 0                                0.0                0.0
# 1                                3.0                3.0
# 2                                0.0                0.0
# 3                                0.0                0.0
# 4                                4.0                4.0
#
#    Avg_IP_Unique_Disease_Count  Avg_IP_Unique_Treatment_Count  OP_Claim_Count  \
# 0                          6.0                            0.0              20
# 1                          9.0                            1.0              70
# 2                          0.0                            0.0             149
# 3                          0.0                            0.0            1165
# 4                          6.0                            0.0              69
#
#    OP_Benf_Count  Avg_OP_InscClaimAmtReimbursed  Avg_OP_DeductibleAmtPaid  \
# 0             19                     382.000000                  0.000000
# 1             66                     466.714286                  1.000000
# 2            138                     350.134228                  2.080537
# 3            495                     241.124464                  3.175966
# 4             56                     213.188406                  0.869565
#
#    Avg_OP_Claim_Days  Avg_OP_Unique_Disease_Count  \
# 0                0.0                          1.0
# 1                0.0                          1.0
# 2                0.0                          1.0
# 3                0.0                          1.0
# 4                0.0                          1.0
#
#    Avg_OP_Unique_Treatment_Count  Total_Beneficiaries  RenalDisease_Count  \
# 0                            0.0                   24                   8
# 1                            0.0                  117                  22
# 2                            0.0                  138                  20
# 3                            0.0                  495                  79
# 4                            0.0                   58                   9
#
#    Alzheimer_Count  HeartFailure_Count  KidneyDisease_Count  Cancer_Count  \
# 0               10                   6                    7            19
# 1               73                  47                   65           107
# 2               78                  56                   91           122
# 3              330                 232                  317           436
# 4               37                  28                   41            52
#
#    Pulmonary_Count  Depression_Count  Diabetes_Count  IschemicHeart_Count  \
# 0               15                15               4                    2
# 1               84                70              30                   18
# 2              101                78              42                   40
# 3              390               311             181                  148
# 4               46                37              22                   18
#
#    Osteoporosis_Count  RheumatoidArthritis_Count  Stroke_Count  \
# 0                  18                         16            19
# 1                  89                         85           108
# 2                  95                         97           122
# 3                 353                        368           456
# 4                  41                         42            49
#
#    Avg_PartA_Months  Avg_PartB_Months_Mode  Avg_IP_Reimbursement  \
# 0                12                     12          18047.916667
# 1                12                     12           6814.017094
# 2                12                     12           4596.739130
# 3                12                     12           3717.232323
# 4                12                     12           3109.655172
#
#    Avg_IP_Deductible  Avg_OP_Reimbursement  Avg_OP_Deductible
# 0         890.000000           2537.500000         474.916667
# 1         822.632479           2490.598291         664.529915
# 2         454.144928           2095.144928         600.869565
# 3         398.698990           1798.808081         475.965657
# 4         423.517241           1497.241379         430.689655

# %%
# Display the distribution of the target variable (PotentialFraud) to check class balance
df.PotentialFraud.value_counts()
# Out:
# PotentialFraud
# 0    4904
# 1     506
# Name: count, dtype: int64

# %% [markdown]
# Here The data was Imbalanced.

# %% [markdown]
# ### Train, Test Split

# %%
# Prepare features by dropping non-predictive columns (Provider ID and target variable)
X_var = df.drop(columns = ['Provider','PotentialFraud'] )
# Extract the target variable for prediction
y_var = df['PotentialFraud']
# Split the data into training (80%) and test (20%) sets while maintaining class distribution
x_train,x_test,y_train,y_test = train_test_split(X_var,y_var,test_size = 0.2, stratify = y_var, random_state = 42)

# %%
# Print the number of rows and columns in training set
print(x_train.shape)
# Print the number of rows and columns in test set
print(x_test.shape)
# Out:
# (4328, 34)
# (1082, 34)

# %%
# Display the distribution of the target variable in the training set
print(y_train.value_counts())
# Out:
# PotentialFraud
# 0    3923
# 1     405
# Name: count, dtype: int64

# %%
# Display the distribution of the target variable in the test set
print(y_test.value_counts())
# Out:
# PotentialFraud
# 0    981
# 1    101
# Name: count, dtype: int64
